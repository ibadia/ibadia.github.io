# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv("softmax_GRU_DotAttention_BAYESBYBACKPROP_premute-results.csv")
df
# Out:
#       Unnamed: 0  max_attn      meds  classes         bins
# 0              0  0.001532  0.119457        0  (0.0, 0.25]
# 1              1  0.001532  0.034911        1  (0.0, 0.25]
# 2              2  0.001532  0.028146        1  (0.0, 0.25]
# 3              3  0.001532  0.027972        1  (0.0, 0.25]
# 4              4  0.001532  0.055034        0  (0.0, 0.25]
# 5              5  0.001532  0.022565        1  (0.0, 0.25]
# 6              6  0.001532  0.035073        0  (0.0, 0.25]
# 7              7  0.001532  0.055279        1  (0.0, 0.25]
# 8              8  0.001532  0.005683        1  (0.0, 0.25]
# 9              9  0.001532  0.018450        1  (0.0, 0.25]
# 10            10  0.001532  0.030783        1  (0.0, 0.25]
# 11            11  0.001530  0.012815        1  (0.0, 0.25]
# 12            12  0.001531  0.067891        1  (0.0, 0.25]
# 13            13  0.001532  0.019722        1  (0.0, 0.25]
# 14            14  0.001532  0.033387        1  (0.0, 0.25]
# ...

# %%
sns.violinplot(data=df, y="bins", x="max_attn", hue="classes", linewidth=1.0, cut=0.02, inner='quartiles', dodge=True)
